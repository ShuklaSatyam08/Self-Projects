# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir('C:\\Users\\SATYAM KR. SHUKLA')

# %%
train=pd.read_csv('Downloads/archive (1)/train.csv')
test=pd.read_csv('Downloads/archive (1)/test.csv')

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
train.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
train.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
train.shape
# Out:
# (381109, 12)

# %%
test.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
test.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  127037.000000  127037.000000    127037.000000  127037.000000
# mean   444628.000000      38.765903         0.998134      26.459866
# std     36672.567411      15.465814         0.043152      13.209916
# min    381110.000000      20.000000         0.000000       0.000000
# 25%    412869.000000      25.000000         1.000000      15.000000
# 50%    444628.000000      36.000000         1.000000      28.000000
# 75%    476387.000000      49.000000         1.000000      35.000000
# max    508146.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel        Vintage
# count       127037.000000   127037.000000         127037.000000  127037.000000
# mean             0.460039    30524.643576            111.800468     154.318301
# std              0.498403    16945.297103             54.371765      83.661588
# ...

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
Num_col=['Age','Annual_Premium']
Cat_col=['Gender','Driving_License','Region_Code','Previously_Insured','Policy_Sales_Channel','Vintage']

# %%
sns.countplot(data=train,x='Gender',hue='Response')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=train,x='Gender',hue='Previously_Insured')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.relplot(data=train,x='Age',y='Previously_Insured',kind='line')

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=train,x='Age',hue='Previously_Insured')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=train,x='Age',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
sns.countplot(data=train,x='Previously_Insured',hue='Response')
# Out:
# <AxesSubplot:xlabel='Previously_Insured', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Age',y='Vintage',data=train,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Vintage'>
# G:\Python_Anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
train.corr()['Response'].sort_values()
# Out:
# Previously_Insured     -0.341170
# Policy_Sales_Channel   -0.139042
# id                     -0.001368
# Vintage                -0.001050
# Driving_License         0.010155
# Region_Code             0.010570
# Annual_Premium          0.022575
# Age                     0.111147
# Response                1.000000
# Name: Response, dtype: float64

# %%
df=train.groupby(['Gender'])['Driving_License'].count().to_frame().reset_index()
df
# Out:
#    Gender  Driving_License
# 0  Female           175020
# 1    Male           206089

# %%
df=train.groupby(['Vehicle_Age','Response','Gender','Previously_Insured','Vintage'])['id'].count().to_frame().rename(columns={'id':'count'}).reset_index()
df
# Out:
#      Vehicle_Age  Response  Gender  Previously_Insured  Vintage  count
# 0       1-2 Year         0  Female                   0       10    127
# 1       1-2 Year         0  Female                   0       11    146
# 2       1-2 Year         0  Female                   0       12    135
# 3       1-2 Year         0  Female                   0       13    136
# 4       1-2 Year         0  Female                   0       14    118
# ...          ...       ...     ...                 ...      ...    ...
# 4823   > 2 Years         1    Male                   0      296      6
# 4824   > 2 Years         1    Male                   0      297     11
# 4825   > 2 Years         1    Male                   0      298     15
# 4826   > 2 Years         1    Male                   0      299     12
# 4827   > 2 Years         1    Male                   1      200      1
#
# [4828 rows x 6 columns]

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Vehicle_Age',y='count',data=df,hue='Response')
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train['Gender']= train['Gender'].map( {'Female': 0, 'Male': 1} ).astype(int)

# %%
train=pd.get_dummies(train,drop_first=True)

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1         28.0                   0
# 1   2       1   76                1          3.0                   0
# 2   3       1   47                1         28.0                   0
# 3   4       1   21                1         11.0                   1
# 4   5       0   29                1         41.0                   1
#
#    Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0         40454.0                  26.0      217         1
# 1         33536.0                  26.0      183         0
# 2         38294.0                  26.0       27         1
# 3         28619.0                 152.0      203         0
# 4         27496.0                 152.0       39         0
#
#    Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years  Vehicle_Damage_Yes
# 0                     0                      1                   1
# ...

# %%
train=train.rename(columns={"Vehicle_Age_< 1 Year": "Vehicle_Age_le_1_Year", "Vehicle_Age_> 2 Years": "Vehicle_Age_get_2_Years"})
train['Vehicle_Age_le_1_Year']=train['Vehicle_Age_le_1_Year'].astype('int')
train['Vehicle_Age_get_2_Years']=train['Vehicle_Age_get_2_Years'].astype('int')
train['Vehicle_Damage_Yes']=train['Vehicle_Damage_Yes'].astype('int')

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1         28.0                   0
# 1   2       1   76                1          3.0                   0
# 2   3       1   47                1         28.0                   0
# 3   4       1   21                1         11.0                   1
# 4   5       0   29                1         41.0                   1
#
#    Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0         40454.0                  26.0      217         1
# 1         33536.0                  26.0      183         0
# 2         38294.0                  26.0       27         1
# 3         28619.0                 152.0      203         0
# 4         27496.0                 152.0       39         0
#
#    Vehicle_Age_le_1_Year  Vehicle_Age_get_2_Years  Vehicle_Damage_Yes
# 0                      0                        1                   1
# ...

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
ss = StandardScaler()
train[Num_col] = ss.fit_transform(train[Num_col])

# %%
mm = MinMaxScaler()
train[['Annual_Premium']] = mm.fit_transform(train[['Annual_Premium']])



for column in Cat_col:
    train[column] = train[column].astype('str')

# %%
test['Gender'] = test['Gender'].map( {'Female': 0, 'Male': 1} ).astype(int)
test=pd.get_dummies(test,drop_first=True)
test=test.rename(columns={"Vehicle_Age_< 1 Year": "Vehicle_Age_le_1_Year", "Vehicle_Age_> 2 Years": "Vehicle_Age_get_2_Years"})
test['Vehicle_Age_le_1_Year']=test['Vehicle_Age_le_1_Year'].astype('int')
test['Vehicle_Age_get_2_Years']=test['Vehicle_Age_get_2_Years'].astype('int')
test['Vehicle_Damage_Yes']=test['Vehicle_Damage_Yes'].astype('int')

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
ss = StandardScaler()
test[Num_col] = ss.fit_transform(test[Num_col])


mm = MinMaxScaler()
test[['Annual_Premium']] = mm.fit_transform(test[['Annual_Premium']])

for column in Cat_col:
    test[column] = test[column].astype('str')

# %%
from sklearn.model_selection import train_test_split
train_label=train['Response']
train_feat=train.drop(['Response'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(train_feat, train_label, random_state=1201)

# %%
from sklearn.model_selection import RandomizedSearchCV
# from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
# from catboost import CatBoostClassifier
# from scipy.stats import randint
import pickle
# import xgboost as xgb
# import lightgbm as lgb
from sklearn.metrics import accuracy_score
# import packages for hyperparameters tuning
# from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
# from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, KFold, GridSearchCV
from sklearn.metrics import classification_report,confusion_matrix, precision_recall_curve, auc, roc_curve

# %%
rnc=RandomForestClassifier()
rnc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=rnc.predict(X_test)

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93     83820
#            1       0.38      0.08      0.13     11458
#
#     accuracy                           0.87     95278
#    macro avg       0.64      0.53      0.53     95278
# weighted avg       0.83      0.87      0.84     95278

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[82350  1470]
#  [10543   915]]

# %%
prediction.transpose()
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
